# %%
import pandas as pd

# %%
train = pd.read_csv("Train.csv")

# %%
train.head()
# Out:
#             ID                 created_at       site       pm2_5        pm10  \
# 0  ID_0038MG0B  2020-04-23 17:00:00+03:00  USEmbassy    6.819048    7.313810
# 1  ID_008ASVDD  2020-02-23 19:00:00+03:00  USEmbassy   57.456047   67.883488
# 2  ID_009ACJQ9  2021-01-23 04:00:00+03:00     Nakawa  170.009773  191.153636
# 3  ID_00IGMAQ2  2019-12-04 09:00:00+03:00  USEmbassy   49.732821   61.512564
# 4  ID_00P76VAQ  2019-10-01 01:00:00+03:00  USEmbassy   41.630455   51.044545
#
#      s2_pm2_5     s2_pm10  humidity       temp       lat       long  altitude  \
# 0    6.794048    7.838333  0.807417  22.383333  0.299255  32.592686      1199
# 1   55.643488   70.646977  0.712417  25.350000  0.299255  32.592686      1199
# 2  165.308636  191.471591  0.907833  20.616667  0.331740  32.609510      1191
# 3    0.000000    0.000000  0.949667  21.216667  0.299255  32.592686      1199
# 4   41.725000   51.141364  0.913833  18.908333  0.299255  32.592686      1199
#
# ...

# %%
test = pd.read_csv("Test.csv")
test.head()
# Out:
#             ID                 created_at       site      pm2_5       pm10  \
# 0  ID_00OZLF7X  2020-03-13 07:00:00+03:00  USEmbassy  31.900455  35.515455
# 1  ID_00ZI0D98  2020-08-08 10:00:00+03:00   Makerere  53.581818  66.603636
# 2  ID_017GTLAU  2020-08-25 09:00:00+03:00   Makerere  62.377500  71.647500
# 3  ID_01IBM7T2  2020-06-15 16:00:00+03:00  USEmbassy  33.310294  36.958824
# 4  ID_01II27D4  2021-01-13 00:00:00+03:00     Nakawa  64.782045  75.247500
#
#     s2_pm2_5    s2_pm10  humidity       temp       lat       long  altitude  \
# 0  31.672273  37.051818  0.927167  21.175000  0.299255  32.592686      1199
# 1  50.586364  64.651818  0.811583  22.350000  0.333501  32.568561      1233
# 2  59.023333  69.766667  0.902000  20.766667  0.333501  32.568561      1233
# 3  33.060882  38.674412  0.643417  25.483333  0.299255  32.592686      1199
# 4  64.638182  77.108864  0.939667  20.133333  0.331740  32.609510      1191
#
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10932 entries, 0 to 10931
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               10932 non-null  object
#  1   created_at       10932 non-null  object
#  2   site             10932 non-null  object
#  3   pm2_5            10932 non-null  float64
#  4   pm10             10932 non-null  float64
#  5   s2_pm2_5         10932 non-null  float64
#  6   s2_pm10          10932 non-null  float64
#  7   humidity         10926 non-null  float64
#  8   temp             10915 non-null  float64
#  9   lat              10932 non-null  float64
#  10  long             10932 non-null  float64
#  11  altitude         10932 non-null  int64
#  12  greenness        10932 non-null  int64
#  13  landform_90m     10932 non-null  int64
#  14  landform_270m    10932 non-null  int64
#  15  population       10932 non-null  int64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2733 entries, 0 to 2732
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               2733 non-null   object
#  1   created_at       2733 non-null   object
#  2   site             2733 non-null   object
#  3   pm2_5            2733 non-null   float64
#  4   pm10             2733 non-null   float64
#  5   s2_pm2_5         2733 non-null   float64
#  6   s2_pm10          2733 non-null   float64
#  7   humidity         2732 non-null   float64
#  8   temp             2729 non-null   float64
#  9   lat              2733 non-null   float64
#  10  long             2733 non-null   float64
#  11  altitude         2733 non-null   int64
#  12  greenness        2733 non-null   int64
#  13  landform_90m     2733 non-null   int64
#  14  landform_270m    2733 non-null   int64
#  15  population       2733 non-null   int64
# ...

# %%
train.describe().T
# Out:
#                    count         mean          std          min          25%  \
# pm2_5            10932.0    51.543471    34.588032     0.567273    29.370546
# pm10             10932.0    59.794230    38.214016     0.595909    33.740357
# s2_pm2_5         10932.0    48.183486    34.259708     0.000000    26.605675
# s2_pm10          10932.0    56.765928    38.876526     0.000000    30.255752
# humidity         10926.0     0.824849     0.135233     0.307167     0.735000
# temp             10915.0    21.962882     2.803965    16.175000    19.775000
# lat              10932.0     0.314090     0.016704     0.299255     0.299255
# long             10932.0    32.588472     0.013861    32.568561    32.568561
# altitude         10932.0  1207.406696    16.369252  1191.000000  1199.000000
# greenness        10932.0  5166.938986   904.989287  4374.000000  4374.000000
# landform_90m     10932.0    22.570618     3.638757    21.000000    21.000000
# ...

# %%
test.describe().T
# Out:
#                   count         mean          std          min          25%  \
# pm2_5            2733.0    52.115167    36.221644     0.954318    27.844286
# pm10             2733.0    60.320047    39.726532     0.982500    31.470571
# s2_pm2_5         2733.0    48.884620    36.061169     0.000000    25.351591
# s2_pm10          2733.0    57.464163    40.804437     0.000000    28.655714
# humidity         2732.0     0.823830     0.132842     0.320417     0.738292
# temp             2729.0    21.997552     2.777461    16.575000    19.800000
# lat              2733.0     0.314090     0.016706     0.299255     0.299255
# long             2733.0    32.588468     0.013863    32.568561    32.568561
# altitude         2733.0  1207.410538    16.372577  1191.000000  1199.000000
# greenness        2733.0  5166.982437   905.158426  4374.000000  4374.000000
# landform_90m     2733.0    22.569704     3.638394    21.000000    21.000000
# ...

# %%
train.isna().sum()
# Out:
# ID                  0
# created_at          0
# site                0
# pm2_5               0
# pm10                0
# s2_pm2_5            0
# s2_pm10             0
# humidity            6
# temp               17
# lat                 0
# long                0
# altitude            0
# greenness           0
# landform_90m        0
# landform_270m       0
# population          0
# dist_major_road     0
# ref_pm2_5           0
# dtype: int64

# %%
# # convert humidity and temp to numerical
# train['temp'] = pd.to_numeric(train['temp'],errors='coerce')
# train['humidity'] = pd.to_numeric(train['humidity'],errors='coerce')
# # for test
# test['temp'] = pd.to_numeric(test['temp'],errors='coerce')
# test['humidity'] = pd.to_numeric(test['humidity'],errors='coerce')

# %%
# # handling missing value
# train['temp'].fillna(train['temp'].median, inplace=True)
# train['humidity'].fillna(train['humidity'].median, inplace=True)

# %%
# test['temp'].fillna(test['temp'].median, inplace=True)
# test['humidity'].fillna(test['humidity'].median, inplace=True)

# %%
test.isna().sum()
# Out:
# ID                 0
# created_at         0
# site               0
# pm2_5              0
# pm10               0
# s2_pm2_5           0
# s2_pm10            0
# humidity           1
# temp               4
# lat                0
# long               0
# altitude           0
# greenness          0
# landform_90m       0
# landform_270m      0
# population         0
# dist_major_road    0
# dtype: int64

# %%
train['created_at'] =  pd.to_datetime(train['created_at'])
train['year_of_creat'] = train['created_at'].dt.year

# %%
train.year_of_creat
# Out:
# 0        2020
# 1        2020
# 2        2021
# 3        2019
# 4        2019
#          ...
# 10927    2019
# 10928    2019
# 10929    2020
# 10930    2020
# 10931    2020
# Name: year_of_creat, Length: 10932, dtype: int64

# %%
train['created_month'] = train['created_at'].dt.month
train['created_day'] = train['created_at'].dt.day

# %%
train.head()
# Out:
#             ID                created_at       site       pm2_5        pm10  \
# 0  ID_0038MG0B 2020-04-23 17:00:00+03:00  USEmbassy    6.819048    7.313810
# 1  ID_008ASVDD 2020-02-23 19:00:00+03:00  USEmbassy   57.456047   67.883488
# 2  ID_009ACJQ9 2021-01-23 04:00:00+03:00     Nakawa  170.009773  191.153636
# 3  ID_00IGMAQ2 2019-12-04 09:00:00+03:00  USEmbassy   49.732821   61.512564
# 4  ID_00P76VAQ 2019-10-01 01:00:00+03:00  USEmbassy   41.630455   51.044545
#
#      s2_pm2_5     s2_pm10  humidity       temp       lat  ...  altitude  \
# 0    6.794048    7.838333  0.807417  22.383333  0.299255  ...      1199
# 1   55.643488   70.646977  0.712417  25.350000  0.299255  ...      1199
# 2  165.308636  191.471591  0.907833  20.616667  0.331740  ...      1191
# 3    0.000000    0.000000  0.949667  21.216667  0.299255  ...      1199
# 4   41.725000   51.141364  0.913833  18.908333  0.299255  ...      1199
#
#    greenness  landform_90m  landform_270m  population  dist_major_road  \
# ...

# %%
# for test set
test['created_at'] =  pd.to_datetime(test['created_at'])
test['year_of_creat'] = test['created_at'].dt.year
test['created_month'] = test['created_at'].dt.month
test['created_day'] = test['created_at'].dt.day

# %%
test.head()
# Out:
#             ID                created_at       site      pm2_5       pm10  \
# 0  ID_00OZLF7X 2020-03-13 07:00:00+03:00  USEmbassy  31.900455  35.515455
# 1  ID_00ZI0D98 2020-08-08 10:00:00+03:00   Makerere  53.581818  66.603636
# 2  ID_017GTLAU 2020-08-25 09:00:00+03:00   Makerere  62.377500  71.647500
# 3  ID_01IBM7T2 2020-06-15 16:00:00+03:00  USEmbassy  33.310294  36.958824
# 4  ID_01II27D4 2021-01-13 00:00:00+03:00     Nakawa  64.782045  75.247500
#
#     s2_pm2_5    s2_pm10  humidity       temp       lat       long  altitude  \
# 0  31.672273  37.051818  0.927167  21.175000  0.299255  32.592686      1199
# 1  50.586364  64.651818  0.811583  22.350000  0.333501  32.568561      1233
# 2  59.023333  69.766667  0.902000  20.766667  0.333501  32.568561      1233
# 3  33.060882  38.674412  0.643417  25.483333  0.299255  32.592686      1199
# 4  64.638182  77.108864  0.939667  20.133333  0.331740  32.609510      1191
#
# ...

# %%
# now let's drop create columns from train and test

del train['created_at']
del test['created_at']

# %%
train.ref_pm2_5.hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
# Encoding the site column
train.site = pd.get_dummies(train.site,drop_first=True)
test.site = pd.get_dummies(test.site,drop_first=True)

# %%
final = test.ID

# %%
train.ID.value_counts()
# Out:
# ID_3U383CBS    1
# ID_XYZNO6YQ    1
# ID_ARH0XSMF    1
# ID_EPUVL3UJ    1
# ID_D1AG9QEP    1
#               ..
# ID_VF32UVH1    1
# ID_8E0JRUDW    1
# ID_WCS8M15A    1
# ID_M57C0MHX    1
# ID_Z8F6U7M4    1
# Name: ID, Length: 10932, dtype: int64

# %%
train.ID = pd.get_dummies(train.ID,drop_first=True)
test.ID = pd.get_dummies(test.ID,drop_first=True)

# %%
train.head()
# Out:
#    ID  site       pm2_5        pm10    s2_pm2_5     s2_pm10  humidity  \
# 0   0     0    6.819048    7.313810    6.794048    7.838333  0.807417
# 1   1     0   57.456047   67.883488   55.643488   70.646977  0.712417
# 2   0     1  170.009773  191.153636  165.308636  191.471591  0.907833
# 3   0     0   49.732821   61.512564    0.000000    0.000000  0.949667
# 4   0     0   41.630455   51.044545   41.725000   51.141364  0.913833
#
#         temp       lat       long  altitude  greenness  landform_90m  \
# 0  22.383333  0.299255  32.592686      1199       4374            21
# 1  25.350000  0.299255  32.592686      1199       4374            21
# 2  20.616667  0.331740  32.609510      1191       5865            31
# 3  21.216667  0.299255  32.592686      1199       4374            21
# 4  18.908333  0.299255  32.592686      1199       4374            21
#
#    landform_270m  population  dist_major_road  ref_pm2_5  year_of_creat  \
# ...

# %%
train.dtypes
# Out:
# ID                   uint8
# site                 uint8
# pm2_5              float64
# pm10               float64
# s2_pm2_5           float64
# s2_pm10            float64
# humidity           float64
# temp               float64
# lat                float64
# long               float64
# altitude             int64
# greenness            int64
# landform_90m         int64
# landform_270m        int64
# population           int64
# dist_major_road      int64
# ref_pm2_5          float64
# year_of_creat        int64
# created_month        int64
# created_day          int64
# dtype: object

# %%
# train['humidity'] = train['humidity'].astype(float)
# train['temp'] = train['temp'].astype(float)

# %%
train.dtypes
# Out:
# ID                   uint8
# site                 uint8
# pm2_5              float64
# pm10               float64
# s2_pm2_5           float64
# s2_pm10            float64
# humidity           float64
# temp               float64
# lat                float64
# long               float64
# altitude             int64
# greenness            int64
# landform_90m         int64
# landform_270m        int64
# population           int64
# dist_major_road      int64
# ref_pm2_5          float64
# year_of_creat        int64
# created_month        int64
# created_day          int64
# dtype: object

# %%
humidity_mean = train['humidity'].mean()
temp_mean = train['temp'].mean()


train['temp'].fillna(value=temp_mean, inplace=True)
train['humidity'].fillna(value= humidity_mean, inplace=True)
humidity_mean
# Out:
# 0.8248490125060435

# %%
humidity_mean_t = test['humidity'].mean()
temp_mean_t = test['temp'].mean()


test['temp'].fillna(value=temp_mean_t, inplace=True)
test['humidity'].fillna(value= humidity_mean_t, inplace=True)

# %%
train.dtypes
# Out:
# ID                   uint8
# site                 uint8
# pm2_5              float64
# pm10               float64
# s2_pm2_5           float64
# s2_pm10            float64
# humidity           float64
# temp               float64
# lat                float64
# long               float64
# altitude             int64
# greenness            int64
# landform_90m         int64
# landform_270m        int64
# population           int64
# dist_major_road      int64
# ref_pm2_5          float64
# year_of_creat        int64
# created_month        int64
# created_day          int64
# dtype: object

# %%
train.shape, test.shape
# Out:
# ((10932, 20), (2733, 19))

# %%
# selection of features
X = train.drop("ref_pm2_5",1)
y = train.ref_pm2_5

# %%
X.isna().sum()
# Out:
# ID                 0
# site               0
# pm2_5              0
# pm10               0
# s2_pm2_5           0
# s2_pm10            0
# humidity           0
# temp               0
# lat                0
# long               0
# altitude           0
# greenness          0
# landform_90m       0
# landform_270m      0
# population         0
# dist_major_road    0
# year_of_creat      0
# created_month      0
# created_day        0
# dtype: int64

# %%
# # scaling of data
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler(feature_range=(0,1))
# scaled_train = scaler.fit_transform(X)

# %%
# import regression algorithm 
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, cross_val_score

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=.25, random_state=1234)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled_train = scaler.fit_transform(X_train)
scaled_test = scaler.fit_transform(X_test)

# %%
models = {
    "SVM": SVR(),
    "KNN": KNeighborsRegressor(),
    "RF": RandomForestRegressor(),
    "GB": GradientBoostingRegressor(),
    "DTC": DecisionTreeRegressor(),
    "HGB": HistGradientBoostingRegressor(),
    "LR": LinearRegression()
}



for model_name, model in models.items():
    print("Train {}".format(model_name))
    # cross_val_score for each classifier
#     scores = cross_val_score(model, X_train, y_train, cv=5, scoring=metrics.mean_squared_error)
    model.fit(X_train, y_train)
    scores = cross_val_score(model, scaled_train, y_train, cv=5)
    print(scores)
    scores_average = (sum(scores))/(len(scores))
    print(scores_average)

#     print("List of scores for {}: {}".format(model_name, scores))
#     print("The mean score for {}: {}".format(model_name, scores.mean()))
    print("-------------The End------------------")
# Out:
# Train SVM
# [0.73158624 0.6719198  0.63963803 0.74005886 0.73126417]
# 0.7028934175033529
# -------------The End------------------
# Train KNN
# [0.86087516 0.7864649  0.77763912 0.84173836 0.82748549]
# 0.8188406055548993
# -------------The End------------------
# Train RF
# [0.87562129 0.81811523 0.7844877  0.86605375 0.8379444 ]
# 0.8364444733375839
# -------------The End------------------
# Train GB
# [0.87633259 0.82161463 0.78908307 0.86477605 0.84335903]
# 0.8390330750284578
# -------------The End------------------
# Train DTC
# [0.6236087  0.71568135 0.68221933 0.70484866 0.70861615]
# 0.6869948396102152
# -------------The End------------------
# Train HGB
# [0.90005263 0.83559865 0.8171433  0.88895737 0.86359104]
# 0.861068595852766
# -------------The End------------------
# Train LR
# [0.80181247 0.79833837 0.73010083 0.83350252 0.81992028]
# 0.7967348970768992
# -------------The End------------------

# %%
import lightgbm as lgb
model = lgb.LGBMRegressor()
model.fit(scaled_train,y_train)
mean_squared_error(y_test, model.predict(scaled_test), squared=False)
# Out:
# 13.111167076067698

# %%
# Histogradient boosting algorithm
model1 = SVR()
model1.fit(X,y)
mean_squared_error(y_test, model1.predict(X_test), squared=True)
# Out:
# 1213.4609241834219

# %%
y_pred = model.predict(test)

# %%
submission = pd.DataFrame({'ID':final, 'ref_pm2_5':y_pred })
submission.to_csv("submission_df.csv", index=False)
